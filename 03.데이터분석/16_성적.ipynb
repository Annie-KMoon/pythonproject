# %%
import pandas as pd
df = pd.read_csv('data/score.csv', index_col='지원번호')
df_score = df.loc[:,'국어':'사회']
df_score.to_csv('data/학생성적.csv')

# %%
df = pd.read_csv('data/학생성적.csv')
df['지원번호']=df['지원번호'].str.replace('번','')
# df['지원번호'].max().index
# df.info()
df['지원번호']=df['지원번호'].apply(lambda x:int(x)) #전체 int 변환
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   지원번호    8 non-null      int64
#  1   국어      8 non-null      int64
#  2   영어      8 non-null      int64
#  3   수학      8 non-null      int64
#  4   과학      8 non-null      int64
#  5   사회      8 non-null      int64
# dtypes: int64(6)
# memory usage: 512.0 bytes

# %%
df.to_csv('data/학생성적.csv', index=False)

# %%
score = pd.read_csv('data/학생성적.csv')
cols = list(score.columns)
cols
# Out:
# ['지원번호', '국어', '영어', '수학', '과학', '사회']

# %%
for idx in range(len(score)):
    row = score.loc[idx]
    for col in cols:
        print(f'{col}:{row[col]}', end=' ')
    print()
# Out:
# 지원번호:1 국어:90 영어:85 수학:100 과학:95 사회:85
# 지원번호:2 국어:40 영어:35 수학:50 과학:55 사회:25
# 지원번호:3 국어:80 영어:75 수학:70 과학:80 사회:75
# 지원번호:4 국어:40 영어:60 수학:70 과학:75 사회:80
# 지원번호:5 국어:15 영어:20 수학:10 과학:35 사회:10
# 지원번호:6 국어:80 영어:100 수학:95 과학:85 사회:80
# 지원번호:7 국어:55 영어:65 수학:45 과학:40 사회:35
# 지원번호:8 국어:100 영어:85 수학:90 과학:95 사회:95

# %%
index = list(score.index)
index = max(index)+1
index
# Out:
# 8

# %%
no = score['지원번호'].max()
no = no+1
no
# Out:
# np.int64(9)

# %%
score.loc[index] = [no, 0, 0, 0, 0, 0]
score
# Out:
#    지원번호   국어   영어   수학  과학  사회
# 0     1   90   85  100  95  85
# 1     2   40   35   50  55  25
# 2     3   80   75   70  80  75
# 3     4   40   60   70  75  80
# 4     5   15   20   10  35  10
# 5     6   80  100   95  85  80
# 6     7   55   65   45  40  35
# 7     8  100   85   90  95  95
# 8     9    0    0    0   0   0

# %%
#검색
score = pd.read_csv('data/학생성적.csv')
score
# Out:
#    지원번호   국어   영어   수학  과학   사회
# 0     1   90   85  100  95   85
# 1     2   40   35   50  55   25
# 2     3   80   75   70  80   75
# 3     4   40   60   70  75   80
# 4     5   15   20   10  35   10
# 5     6   80  100   95  85   80
# 6     7   55   65   45  40   35
# 7     8  100   85   90  95   95
# 8     9  100   80   60  80  100

# %%
no=input('지원번호>')
filt = score['지원번호']==int(no)
idxs = score[filt].index
print(idxs)
if len(idxs)==0:
    print("검색데이터가 없습니다.")
else:
    row = score.loc[idxs[0]]
    for col in cols:
        print(f'{col}:{row[col]}')
# Out:
# Index([], dtype='int64')
# 검색데이터가 없습니다.

# %%
no=input('삭제할 번호>')
filt = score['지원번호']==int(no)
idxs = score[filt].index
if len(idxs)==0:
    print("삭제할 데이터가 없습니다.")
else:
    row = score.loc[idx[0]]
    for col in cols:
        print(f'{col}:{row[col]}', end=" ")
    score.drop(index=idx[0], inplace=True)
# Out:
# 지원번호:3 국어:80 영어:75 수학:70 과학:80 사회:75

# %%
score
# Out:
#    지원번호   국어   영어   수학  과학   사회
# 0     1   90   85  100  95   85
# 1     2   40   35   50  55   25
# 3     4   40   60   70  75   80
# 4     5   15   20   10  35   10
# 5     6   80  100   95  85   80
# 6     7   55   65   45  40   35
# 7     8  100   85   90  95   95
# 8     9  100   80   60  80  100

# %%
score = pd.read_csv('data/학생성적.csv')
score.sort_values('국어', ascending=False)
# Out:
#    지원번호   국어   영어   수학  과학  사회
# 6     9  100   80   20  80  90
# 7    10  100   80   70   0  90
# 5     8  100   85   90  95  95
# 0     1   90   85  100  95  85
# 3     6   80  100   95  85  80
# 4     7   55   65   45  40  35
# 1     4   40   60   70  75  80
# 2     5   15   20   10  35  10

# %%
for idx in score.index:
    row = score.loc[idx]
